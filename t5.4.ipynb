# %% [markdown]
# ![image.png](attachment:411cc3bf-0d9b-4601-82a1-294f429e7552.png)

# %%
import math
def isprime(x):
    for i in range(2,int(math.sqrt(x))+1):
        if x%i == 0:
            return False
    return True

tmp = input()
a,b = tmp.split()
a = int(a)
b = int(b)

for i in range(a,b):
    if isprime(i) and isprime(i+2) and i+2 <= b:
        print(str(i)+" "+str(i+2))
        break;
    if i ==b-1:
        print("none")

# %% [markdown]
# ![image.png](attachment:98f1c0cb-9ec7-4871-9dd2-402bff69302f.png)

# %% [markdown]
# ![image.png](attachment:c3057b73-3d92-4517-9edb-472e41ebd040.png)

# %%
a = int(input())
num = []
while(a/10):
    t = a%10
    num.append(t)
    a = (a-t)/10.0
num = num[::-1]
l = len(num)//2
ta = 0
tb = 0
for i in range(l):
    ta = ta + num[i]*10**(l-i-1)
for i in range(l,len(num)):
    tb = tb + num[i]*10**(i-l)
ans = int(ta+tb)
print(ans)

# %% [markdown]
# ![image.png](attachment:56c6cf9d-2bb4-4d80-ac10-21d073407d1e.png)

# %% [markdown]
# ![image.png](attachment:928861e8-1a67-4d41-ac01-030962b72ed4.png)

# %%
a = int(input())
num = []
while(a/10):
    t = a%10
    num.append(t)
    a = (a-t)/10.0
num = num[::-1]
l = len(num)//2+1
if (len(num)%2) ==0:
    l = len(num)//2
else:
    l = len(num)//2+1
ta = 0
tb = 0
for i in range(l):
    ta = ta + num[i]*10**(i)
for i in range(l,len(num)):
    tb = tb + num[i]*10**(len(num)-i-1)
ans = int(ta+tb)
print(ans)

# %% [markdown]
# ![image.png](attachment:5660b4b8-94b2-45f6-901d-867f8804c57b.png)

# %% [markdown]
# ![image.png](attachment:41ea5b85-aecc-4f0b-9e98-0018355d6d1c.png)

# %%
import math
def isprime(x):
    for i in range(2,int(math.sqrt(x))+1):
        if x%i == 0:
            return False
    return True

a,b = map(int,input().split())
for i in range(a,b):
    if i%5==1 and i%7==3 and i%11==5 and isprime(i):
        print(i)
        break
    if i == b-1:
        print("none")

# %% [markdown]
# ![image.png](attachment:883bfaf2-97b3-4103-9605-a1e83d13b84d.png)

# %% [markdown]
# ![image.png](attachment:c4844d24-bf07-4a73-a0d1-29a7aa62e572.png)

# %%
a,b = map(float,input().split())
print("%.2f %.2f"%(a * 2.54,b / 2.54))

# %% [markdown]
# ![image.png](attachment:bfb38e67-bf98-49e4-873b-ff8f43967729.png)

# %% [markdown]
# ![image.png](attachment:53c16179-10e1-41a0-be5c-d8091e209743.png)

# %%
# ans = [1]*15
# def printn():
#     for i in range(1,16):
#         j = 1
#         t = 0.0
#         while True:
#             t += 1.0/j
#             if t > i:
#                 ans[i-1] = j
#                 break
#             j+=1
#             # print(j)
# printn()
# a = int(input())
# print(ans)

# 先计算结果

# 然后打表

# 打表方法
ans =[2, 4, 11, 31, 83, 227, 616, 1674, 4550, 12367, 33617, 91380, 248397, 675214, 1835421]
a = int(input())
print(ans[a-1])

# %% [markdown]
# ![image.png](attachment:681ba78a-faa8-4791-a03b-f419eba4ccf6.png)

# %% [markdown]
# ![image.png](attachment:26c825ee-f8d6-4c0c-87a7-af471fd86e6c.png)

# %%
# num = map(int,input().split())
t = list(map(int,input().split()))
t = t[1:]
print(max(t))

# %% [markdown]
# ![image.png](attachment:12b7e6db-8169-4634-89ae-9b8fa9939ca6.png)

# %% [markdown]
# ![image.png](attachment:4423a60a-e754-44a0-ada0-e2ec60a279b4.png)

# %%
n = int(input())
a = []
for i in range(n):
    t = int(input())
    a.append(t)
ans = sum(a)/len(a)
print("%.2f"%ans)

# %% [markdown]
# ![image.png](attachment:4f642f14-7e51-4978-a59e-5333472d8cf5.png)

# %% [markdown]
# ![image.png](attachment:356c6aa3-b5a9-4e0f-877d-a990c0d627f4.png)

# %%
import math
def nthPrime(n):
    index = 1
    result = 2
    while index <= n:
        flag = 1   #先假定是质数
        #判断是否为素数
        for i in range(2,int(math.sqrt(result))+1):
            if result % i == 0:
                flag = 0
                break
        if flag:
            index += 1
        result += 1
    return result - 1
n = int(input())
print(nthPrime(n))

# %% [markdown]
# ![image.png](attachment:8b96af6d-5131-46d1-b691-99bd0fbe45d8.png)

# %% [markdown]
# ![image.png](attachment:be8948f0-820f-4022-ae49-949c033aadba.png)

# %%
a = int(input())
ans = 1;
for i in range(1,a+1):
    ans *= i
print(ans)

# %% [markdown]
# ![image.png](attachment:90875898-34ab-4a76-a6b2-49ac2b2f1247.png)

# %% [markdown]
# ![image.png](attachment:931eaccf-5e56-49d3-bf88-ec0e94debdca.png)

# %%
isnp = [0]*50005
# 欧筛
def init(n):
    i = 2
    while i*i<=n:
        if isnp[i]==0:
            j = i*i
            while j <= n:
                isnp[j] = 1;
                j+=i
        i+=1
n = int(input())
init(n)
ans = 0
for i in range(2,n+1):
    if isnp[i]==0:
        ans += 1
print(ans)
# Out:
#  10
# 4

# %% [markdown]
# ![image.png](attachment:92cfceef-bf69-4758-b862-ca7d224d35cb.png)

# %% [markdown]
# ![image.png](attachment:c9c676d4-f46a-408d-8485-dc3c0fe4e35a.png)

# %%
# def getnum(n):
#     for x in range (1,n):
#         sum = 0
#         for y in range(1,int(x/2)+1):
#             if x%y==0:
#                 sum = sum + y
#         if sum == x:
#             print(x)

# getnum(30000)


# 打表
n = int(input())
num = [6,28,496,8128]
for i in num:
    if n > i:
        print(i)
# Out:
#  7
# 6

# %% [markdown]
# ![image.png](attachment:ef70b5fc-16ce-47b3-ac75-9f0bde748e51.png)

# %% [markdown]
# ![image.png](attachment:9e184f17-fa87-4f08-b4a7-fa590e8ce041.png)

# %%
isnp = [0]*50005
# 欧筛
def init(n):
    i = 2
    while i*i<=n:
        if isnp[i]==0:
            j = i*i
            while j <= n:
                isnp[j] = 1;
                j+=i
        i+=1
init(10005)
n = int(input())
ans = []
for i in range(n//2+1):
    if isnp[i] == 0 and isnp[n-i] == 0:
        ans.append(i*(n-i))
print(max(ans))
# Out:
#  50
# 589

# %% [markdown]
# ![image.png](attachment:3b0d1300-63cf-4507-b3c8-3e82af9c43b6.png)
